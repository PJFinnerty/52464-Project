# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import hist
import seaborn as sns
# Set seed of the generator
rng = np.random.default_rng(0)

# %%
# list containing 61 strings of countrys (beginning with just 3)
temp_df1 = pd.DataFrame({"Countries": ["India", "India", "India", "India", "India", "India", "India", "India", "India", "India", 
            "India", "India", "India", "India", "India", "India", "India", "India", "India", "India", 
            "India",
          "Indonesia", "Indonesia", "Indonesia", "Indonesia", "Indonesia", "Indonesia", "Indonesia", 
          "Indonesia","Indonesia","Indonesia",
          "Indonesia", "Indonesia", "Indonesia", "Indonesia", "Indonesia", "Indonesia", "Indonesia", 
          "Indonesia","Indonesia","Indonesia", "Indonesia",
          "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", 
            "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", "Myanmar", 
            "Myanmar"],
                    
           "Years": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
         2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
         2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
         2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
         2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
         2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020] })

# %% [markdown]
# ### Prevelance Variable

# %%
# Use np.uniform() to create a range of random 60 floats to represent the deaths per 100000
valence1 = np.linspace(21.5, 52.7, 2)
prevalence1 = pd.DataFrame(valence1)

valence2= np.linspace(201.5, 252.7, 7)
prevalence2 = pd.DataFrame(valence2)

frames = [prevalence1, prevalence2]

result = pd.concat(frames)
result

# Round to 2 decimal places and assign new variable

prev_poisson = pd.DataFrame(rng.poisson(23, len(prevalence1)), index=prevalence1, columns=["Prevelance"])
# India
#dd
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-4e3de9a52747> in <module>
#      13 # Round to 2 decimal places and assign new variable
#      14
# ---> 15 prev_poisson = pd.DataFrame(rng.poisson(23, len(prevalence1)), index=prevalence1, columns=["Prevelance"])
#      16 # India
#      17 #dd
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     462                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     463             else:
# --> 464                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     465
#     466         # For data is list-like, or Iterable (will consume into list)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     179                 ) from orig
#     180
# --> 181     index, columns = _get_axes(*values.shape, index=index, columns=columns)
#     182     values = values.T
#     183
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _get_axes(N, K, index, columns)
#     422         index = ibase.default_index(N)
#     423     else:
# --> 424         index = ensure_index(index)
#     425
#     426     if columns is None:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in ensure_index(index_like, copy)
#    5356             index_like = copy(index_like)
#    5357
# -> 5358     return Index(index_like)
#    5359
#    5360
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     418
#     419         elif hasattr(data, "__array__"):
# --> 420             return Index(np.asarray(data), dtype=dtype, copy=copy, name=name, **kwargs)
#     421         elif data is None or is_scalar(data):
#     422             raise cls._scalar_data_error(data)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     392                 return UInt64Index(data, copy=copy, dtype=dtype, name=name)
#     393             elif is_float_dtype(data.dtype):
# --> 394                 return Float64Index(data, copy=copy, dtype=dtype, name=name)
#     395             elif issubclass(data.dtype.type, np.bool) or is_bool_dtype(data):
#     396                 subarr = data.astype("object")
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\numeric.py in __new__(cls, data, dtype, copy, name)
#      76         if subarr.ndim > 1:
#      77             # GH#13601, GH#20285, GH#27125
# ---> 78             raise ValueError("Index data must be 1-dimensional")
#      79
#      80         name = maybe_extract_name(name, data, cls)
#
# ValueError: Index data must be 1-dimensional

# %% [markdown]
# ### Consumption (Per Capita) Variable

# %%
# Generate 60 random integers in the range 500-200 to no. of cigarettes consumed per person (15 years or older)
per_capita1 = rng.integers(low=500, high=2000, size=(63,))

# %% [markdown]
# ### Government Control Rating (0.0 - 6.0)

# %%
# Use np.uniform() to create a range of random 60 floats to represent the rating of restrictions against smoking companies
rating1 = rng.uniform(low=0.5, high= 3.0, size=(63,) )
# Round to 1 decimal place and assign new variable
control_rate1 = rating1.round(1)

# %% [markdown]
# ### Use the ravel() Method to Combine Columns for 1. Prevelance, 2. Consumption and 3. Control

# %%
# Create dataframe of numeric variables using ravel() method
temp_df2 = pd.DataFrame({'Prevalence (%)': prevalence.ravel(), 
                     'Consumption': per_capita1.ravel(), 'Control Rating': control_rate1.ravel(),  })

# %% [markdown]
# ### Degree of Influence of Tobacco Lobbying
#
# The list of categories for the Influence variable has not yet bee

# %%
# Create a third dataframe for the Influence variable leaving the square brackets empty - categories will
# populated based off Control Rating variable values
temp_df3 = pd.DataFrame({"Influence": ["Moderate", "Moderate", "Moderate", "Moderate","Moderate",
                       "Moderate", "Moderate", "Moderate", "Moderate","Moderate",
                       "Moderate", "Moderate",
                       "Significant", "Significant", "Significant", "Significant", "Significant", 
                       "Significant", "Significant", 
                       "Strong", "Strong", 
                       
                    "Moderate", "Moderate", "Moderate", "Moderate", "Significant", "Significant", "Significant", 
                    "Significant", "Significant", "Significant", "Significant", "Significant", "Significant", 
                    "Significant", "Significant", "Strong", "Strong", "Strong", "Strong", "Strong", "Strong", 
                       
                    "Moderate", "Moderate", "Moderate", "Moderate", "Significant", "Significant", "Significant", 
                    "Significant", "Significant", "Significant", "Significant", "Significant", "Significant", 
                    "Significant", "Significant", "Strong", "Strong", "Strong", "Strong", "Strong", "Strong"] } )

# %% [markdown]
# ### Concatenate Dataframes into Dataset for Low-Income Countries

# %%
# Concatenate the dataframes along the x-axis, setting the join parameter to 'inner'
dataset1 = pd.concat([temp_df1, temp_df2, temp_df3], axis=1, join='inner')
dataset1.head(5)
# Out:
#   Countries  Years  Prevalence (%)  Consumption  Control Rating Influence
# 0     India   2000       21.500000         1083             2.7  Moderate
# 1     India   2001       22.003226         1741             1.1  Moderate
# 2     India   2002       22.506452         1935             0.8  Moderate
# 3     India   2003       23.009677         1040             1.2  Moderate
# 4     India   2004       23.512903          723             2.0  Moderate

# %% [markdown]
# #### Altering the 'Influence' Variable
#
# In the first 10 lines of data printed above, the Influence variable has not yet been made dependent on the Control Rating variable.
#
# In order to do this we use Pandas .loc() method and enter the parameters of 'Control Rating' that the 'Influence' column should interpret.
#
# For e.g. if control rate is greater than or equal to 1, but less than 2.5, the 'Influence' datapoint for that row should read "Significant". This indicates that countries with a Contrl Rating of 1.0-2.5 exhibit a significant level of influence from the tobacco industry.

# %%
# Use the loc() on dataset1 to access the control rating read the value and interpret the value of Control Rating

dataset1.loc[(dataset1["Control Rating"] >= 0) & (dataset1["Control Rating"] < 1), "Influence"] = "Weak"
dataset1.loc[(dataset1["Control Rating"] >= 1) & (dataset1["Control Rating"] < 2.5), "Influence"] = "Moderate"
dataset1.loc[(dataset1["Control Rating"] >= 2.5) & (dataset1["Control Rating"] < 4.0), "Influence"] = "Significant"
dataset1.loc[(dataset1["Control Rating"] >= 4.0) & (dataset1["Control Rating"] < 5.0), "Influence"] = "Strong"
dataset1.head(8)

# Print the top 10 rows
dataset1[['Control Rating', 'Influence']].head(10)
# Out:
#    Control Rating    Influence
# 0             2.7  Significant
# 1             1.1     Moderate
# 2             0.8         Weak
# 3             1.2     Moderate
# 4             2.0     Moderate
# 5             1.9     Moderate
# 6             2.5  Significant
# 7             1.9     Moderate
# 8             1.2     Moderate
# 9             1.5     Moderate

# %% [markdown]
# Looking at the first 8 values for India, we can see that the Influence variable is determined based off the values from Control Rating.

# %%
dataset1.head(5)
# Out:
#   Countries  Years  Prevalence (%)  Consumption  Control Rating    Influence
# 0     India   2000       21.500000         1083             2.7  Significant
# 1     India   2001       22.003226         1741             1.1     Moderate
# 2     India   2002       22.506452         1935             0.8         Weak
# 3     India   2003       23.009677         1040             1.2     Moderate
# 4     India   2004       23.512903          723             2.0     Moderate

# %% [markdown]
# #### Altering the 'Influence' Variable
#
# In the first 20 lines of data printed above, the Influence variable has not yet been made dependent on the Control Rating variable.
#
# In order to do this we use Pandas .loc() method and enter the parameters of 'Control Rating' that the 'Influence' column should interpret.
#
# For e.g. if control rate is greater than or equal to 1, but less than 2.5, the 'Influence' datapoint for that row should read "Significant". This indicates that countries with a Contrl Rating of 1.0-2.5 exhibit a significant level of influence from the tobacco industry.

# %%
# Use the loc() on dataset1 to access the control rating read the value and interpret the value of 
#dataset1.loc[(dataset1["Control Rating"] >= 0) & (dataset1["Control Rating"] < 1), "Influence"] = "Strong"
#dataset1.loc[(dataset1["Control Rating"] >= 1) & (dataset1["Control Rating"] < 2.5), "Influence"] = "Significant"
#dataset1.loc[(dataset1["Control Rating"] >= 2.5) & (dataset1["Control Rating"] < 4.0), "Influence"] = "Moderate"
#dataset1.loc[(dataset1["Control Rating"] >= 4.0) & (dataset1["Control Rating"] < 5.0), "Influence"] = "Moderate"
#dataset1

# %% [markdown]
# ## High Income Countries Dataset

# %% [markdown]
# ### Countries and Years Variables

# %%
# list containing 61 strings of countrys (beginning with just 3)
temp_df4 = pd.DataFrame({"Countries": ["Austria",  "Austria",  "Austria",  "Austria",  "Austria",  "Austria",  "Austria",  
"Austria",  "Austria", "Austria", "Austria",  "Austria",  "Austria",  "Austria",  "Austria",  "Austria",  "Austria",  
"Austria",  "Austria", "Austria", "Austria",
                                  
"France", "France", "France", "France", "France", "France", "France", "France", "France", "France", "France", "France", 
"France", "France", "France", "France", "France", "France", "France", "France", "France", 
                    
"Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden", 
"Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden", "Sweden"],
                    
        
           "Years": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
         2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
         2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
         2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
         2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
         2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020] })

# %% [markdown]
# ### Prevelance Variable

# %%
# Use np.uniform() to create a range of random 60 floats to represent the deaths per 100000
perc2 = rng.uniform(low=5, high=38.5, size=(63,))
# Round to 2 decimal places and assign new variable
prevelance2 = perc2.round(1)

# %% [markdown]
# ### Consumption (Per Capita) Variable

# %%
# Generate 60 random integers in the range 500-200 to no. of cigarettes consumed per person (15 years or older)
per_capita2 = rng.integers(low=100, high=2000, size=(63,))

# %% [markdown]
# ### Government Control Rating (0.0 - 5.0)

# %%
# Use np.uniform() to create a range of random 60 floats to represent the rating of restrictions against smoking companies
rating2 = rng.uniform(low=3.5, high= 4.7, size=(63,) )
# Round to 1 decimal place and assign new variable
control_rate2 = rating2.round(1)

# %% [markdown]
# ### Use the ravel() Method to Combine Columns for 1. Prevelance, 2. Consumption and 3. Control

# %%
# Create dataframe of numeric variables using ravel() method
temp_df5 = pd.DataFrame({'Control Rating': control_rate2.ravel(), 'Prevelance (%)': prevelance2.ravel(), 
                     'Consumption': per_capita2.ravel() })

# %% [markdown]
# ### Degree of Influence of Tobacco Lobbying

# %%
temp_df6 = pd.DataFrame({"Influence": ["Moderate", "Moderate", "Moderate", "Moderate","Moderate",
                       "Moderate", "Moderate", "Moderate", "Moderate","Moderate",
                       "Moderate", "Moderate",
                       "Significant", "Significant", "Significant", "Significant", "Significant", 
                       "Significant", "Significant", 
                       "Strong", "Strong", 
                       
                    "Moderate", "Moderate", "Moderate", "Moderate", "Significant", "Significant", "Significant", 
                    "Significant", "Significant", "Significant", "Significant", "Significant", "Significant", 
                    "Significant", "Significant", "Strong", "Strong", "Strong", "Strong", "Strong", "Strong", 
                       
                    "Moderate", "Moderate", "Moderate", "Moderate", "Significant", "Significant", "Significant", 
                    "Significant", "Significant", "Significant", "Significant", "Significant", "Significant", 
                    "Significant", "Significant", "Strong", "Strong", "Strong", "Strong", "Strong", "Strong"] } )

# %%
# Concatenate the dataframes along the x-axis
dataset2 = pd.concat([temp_df4, temp_df6, temp_df5], axis=1, join='inner')
dataset2
# Out:
#    Countries  Years Influence  Control Rating  Prevelance (%)  Consumption
# 0    Austria   2000  Moderate             4.7            34.0         1964
# 1    Austria   2001  Moderate             4.4             7.0          626
# 2    Austria   2002  Moderate             4.1            17.8          342
# 3    Austria   2003  Moderate             4.0            19.4         1228
# 4    Austria   2004  Moderate             4.6            21.4          239
# ..       ...    ...       ...             ...             ...          ...
# 58    Sweden   2016    Strong             3.7            34.3         1686
# 59    Sweden   2017    Strong             4.0            20.8          260
# 60    Sweden   2018    Strong             4.4            35.6          825
# 61    Sweden   2019    Strong             4.0            30.7         1066
# 62    Sweden   2020    Strong             4.2            35.7          718
#
# [63 rows x 6 columns]

# %%
pd.set_option('display.max_rows', 200)

frames = [dataset1, dataset2]

v = pd.concat(frames)
v
# Out:
#     Countries  Years  Prevelance (%)  Consumption  Control Rating    Influence
# 0       India   2000            41.4         1434             2.9  Significant
# 1       India   2001            29.9         1370             0.9         Weak
# 2       India   2002            22.8         1848             2.9  Significant
# 3       India   2003            22.0          948             2.7  Significant
# 4       India   2004            46.9         1853             2.6  Significant
# 5       India   2005            50.0         1507             1.7     Moderate
# 6       India   2006            40.4         1835             1.1     Moderate
# 7       India   2007            44.3          799             2.5  Significant
# 8       India   2008            38.5         1637             2.8  Significant
# 9       India   2009            50.7         1913             1.2     Moderate
# 10      India   2010            47.0          572             1.8     Moderate
# 11      India   2011            21.6         1047             1.6     Moderate
# 12      India   2012            48.3         1454             2.8  Significant
# 13      India   2013            22.5          658             0.6         Weak
# 14      India   2014            44.3         1265             2.3     Moderate
# 15      India   2015            27.0         1443             2.0     Moderate
# 16      India   2016            48.4         1645             0.6         Weak
# 17      India   2017            38.4         1890             2.3     Moderate
# 18      India   2018            30.9         1114             0.5         Weak
# 19      India   2019            34.7         1160             2.4     Moderate
# 20      India   2020            22.4         1211             1.8     Moderate
# 21  Indonesia   2000            25.4         1931             2.8  Significant
# 22  Indonesia   2001            42.4          793             0.7         Weak
# 23  Indonesia   2002            41.7         1249             2.6  Significant
# 24  Indonesia   2003            40.7          574             0.7         Weak
# 25  Indonesia   2004            33.5         1137             1.4     Moderate
# 26  Indonesia   2005            52.6         1917             1.6     Moderate
# 27  Indonesia   2006            52.1         1430             2.9  Significant
# 28  Indonesia   2007            42.9         1024             1.9     Moderate
# 29  Indonesia   2008            41.8         1992             1.1     Moderate
# 30  Indonesia   2009            43.0         1405             1.1     Moderate
# 31  Indonesia   2010            33.6         1923             2.7  Significant
# 32  Indonesia   2011            25.7          524             1.1     Moderate
# 33  Indonesia   2012            44.0         1190             0.8         Weak
# 34  Indonesia   2013            37.9         1752             1.2     Moderate
# 35  Indonesia   2014            31.2         1636             2.0     Moderate
# 36  Indonesia   2015            36.7         1111             1.9     Moderate
# 37  Indonesia   2016            49.3         1246             2.5  Significant
# 38  Indonesia   2017            50.6         1130             1.9     Moderate
# 39  Indonesia   2018            32.7         1293             1.2     Moderate
# 40  Indonesia   2019            39.3          845             1.5     Moderate
# 41  Indonesia   2020            31.5         1678             2.5  Significant
# 42    Myanmar   2000            40.0          616             2.1     Moderate
# 43    Myanmar   2001            32.0         1121             2.9  Significant
# 44    Myanmar   2002            33.7          922             1.4     Moderate
# 45    Myanmar   2003            49.3         1601             1.9     Moderate
# 46    Myanmar   2004            28.6         1623             2.0     Moderate
# 47    Myanmar   2005            40.9         1566             2.6  Significant
# 48    Myanmar   2006            24.1         1886             0.9         Weak
# 49    Myanmar   2007            47.5         1898             1.5     Moderate
# 50    Myanmar   2008            46.1          776             2.8  Significant
# 51    Myanmar   2009            29.0          672             0.6         Weak
# 52    Myanmar   2010            48.8          698             2.6  Significant
# 53    Myanmar   2011            23.3         1593             1.5     Moderate
# 54    Myanmar   2012            32.0         1955             2.6  Significant
# 55    Myanmar   2013            26.2         1891             0.5         Weak
# 56    Myanmar   2014            35.6         1502             1.4     Moderate
# 57    Myanmar   2015            46.3         1951             0.7         Weak
# 58    Myanmar   2016            28.7         1806             2.1     Moderate
# 59    Myanmar   2017            23.1          522             1.2     Moderate
# 60    Myanmar   2018            34.1          678             2.3     Moderate
# 61    Myanmar   2019            27.7         1795             2.9  Significant
# 62    Myanmar   2020            24.3          623             0.8         Weak
# 0     Austria   2000            34.0         1964             4.7     Moderate
# 1     Austria   2001             7.0          626             4.4     Moderate
# 2     Austria   2002            17.8          342             4.1     Moderate
# 3     Austria   2003            19.4         1228             4.0     Moderate
# 4     Austria   2004            21.4          239             4.6     Moderate
# 5     Austria   2005            37.7          346             3.6     Moderate
# 6     Austria   2006            31.0          233             4.4     Moderate
# 7     Austria   2007            15.3          500             4.4     Moderate
# 8     Austria   2008            14.0         1750             4.5     Moderate
# 9     Austria   2009            33.9         1378             3.9     Moderate
# 10    Austria   2010            34.5         1304             4.5     Moderate
# 11    Austria   2011            22.1         1972             3.8     Moderate
# 12    Austria   2012            16.5         1043             3.9  Significant
# 13    Austria   2013            38.3          175             4.0  Significant
# 14    Austria   2014            15.6          410             4.1  Significant
# 15    Austria   2015            11.1          594             3.6  Significant
# 16    Austria   2016            34.5         1380             4.0  Significant
# 17    Austria   2017            32.2          778             3.5  Significant
# 18    Austria   2018            27.4          704             4.4  Significant
# 19    Austria   2019            37.1          313             4.5       Strong
# 20    Austria   2020            36.0         1450             3.7       Strong
# 21     France   2000            30.1          146             4.3     Moderate
# 22     France   2001            33.8          974             4.5     Moderate
# 23     France   2002            13.3         1514             4.7     Moderate
# 24     France   2003             9.7         1064             4.5     Moderate
# 25     France   2004            27.4         1405             4.0  Significant
# 26     France   2005            28.9         1600             4.7  Significant
# 27     France   2006            10.6          527             4.7  Significant
# 28     France   2007            18.3          276             4.1  Significant
# 29     France   2008            35.5          207             4.4  Significant
# 30     France   2009            23.8         1199             4.6  Significant
# 31     France   2010            24.4          601             4.1  Significant
# 32     France   2011            11.5          474             4.5  Significant
# 33     France   2012            22.6         1496             4.3  Significant
# 34     France   2013            22.5         1635             3.9  Significant
# 35     France   2014             8.0         1913             4.4  Significant
# 36     France   2015            37.9         1028             4.2       Strong
# 37     France   2016            24.1         1092             3.6       Strong
# 38     France   2017             5.2         1978             4.0       Strong
# 39     France   2018            30.9         1057             3.6       Strong
# 40     France   2019            37.8          447             4.1       Strong
# 41     France   2020            24.8          585             4.0       Strong
# 42     Sweden   2000            15.7         1929             4.0     Moderate
# 43     Sweden   2001            11.3          182             4.2     Moderate
# 44     Sweden   2002            27.5         1621             3.6     Moderate
# 45     Sweden   2003            11.5         1330             4.6     Moderate
# 46     Sweden   2004            24.4         1014             4.3  Significant
# 47     Sweden   2005            25.2         1683             4.5  Significant
# 48     Sweden   2006            37.2         1645             4.6  Significant
# 49     Sweden   2007             7.4          935             4.2  Significant
# 50     Sweden   2008            21.7         1245             3.5  Significant
# 51     Sweden   2009            29.9         1551             4.4  Significant
# 52     Sweden   2010            10.9         1344             4.2  Significant
# 53     Sweden   2011            18.0         1022             4.5  Significant
# 54     Sweden   2012             7.1         1836             4.1  Significant
# 55     Sweden   2013            29.3         1777             4.5  Significant
# 56     Sweden   2014             7.9          224             4.7  Significant
# 57     Sweden   2015            18.2         1139             3.9       Strong
# 58     Sweden   2016            34.3         1686             3.7       Strong
# 59     Sweden   2017            20.8          260             4.0       Strong
# 60     Sweden   2018            35.6          825             4.4       Strong
# 61     Sweden   2019            30.7         1066             4.0       Strong
# 62     Sweden   2020            35.7          718             4.2       Strong

# %%
# Create dataframe for list of strings (countrys) - Split the list to have the first element as a column and the rest as 
# data 
#temp_df7 = list(zip(*[iter(dataset1)]))
temp_df8 = pd.DataFrame(dataset1[1:], columns=dataset2[1])

# Create a variable listing both dataframes together
#dataframes = [temp_df1, temp_df2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-5a88b5225883> in <module>
#       2 # data
#       3 #temp_df7 = list(zip(*[iter(dataset1)]))
# ----> 4 temp_df8 = pd.DataFrame(dataset1[1:], columns=dataset2[1])
#       5
#       6 # Create a variable listing both dataframes together
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1

# %%
# Use np.uniform() to create a range of random 60 floats to represent the rating of restrictions against smoking companies
rating2 = rng.uniform(low=0.01, high=4.99, size=(63,))
# Round to 1 decimal place1 and assign new variable
control_rate2 = rating2.round(1)
print(control_rate)

# %%
x = rng.integers(low=2.5, high=4.8, size=(63,))
y = a*x**(a-1.)

# %%
a = 5. # shape
samples = 100
s = np.random.power(6, 63)
s
# Out:
# array([0.93263736, 0.67367287, 0.75999104, 0.85245628, 0.9421442 ,
#        0.99271363, 0.74480191, 0.98886243, 0.90445091, 0.95902654,
#        0.76381203, 0.81018355, 0.95734795, 0.8559463 , 0.95674811,
#        0.95965258, 0.99085017, 0.86183174, 0.90735769, 0.99166627,
#        0.81141999, 0.98418397, 0.93579075, 0.74768277, 0.93964497,
#        0.83586822, 0.5750916 , 0.75846416, 0.86681792, 0.8783417 ,
#        0.95895872, 0.87649011, 0.45892769, 0.96844315, 0.98594206,
#        0.88844405, 0.65241467, 0.59282069, 0.7943262 , 0.7955601 ,
#        0.7740449 , 0.81373338, 0.55286014, 0.76675695, 0.92199839,
#        0.87401611, 0.78084473, 0.99122177, 0.74131548, 0.91717476,
#        0.96578138, 0.9017754 , 0.97468701, 0.85907645, 0.91812133,
#        0.84821491, 0.73957688, 0.89054105, 0.74069257, 0.84916594,
#        0.9610006 , 0.76757621, 0.75756159])

# %%
a = 63. # shape
samples = (2.5, 4.4)
s = rng.exponential(scale=0.6, size=63)
s
# Out:
# array([0.82552756, 0.37607861, 0.04120355, 0.07909776, 1.92404114,
#        0.13688172, 0.02823741, 0.08614592, 0.26414697, 1.42498149,
#        1.13635284, 1.07031822, 0.84672716, 0.08326833, 0.36889453,
#        0.68510596, 0.06102769, 1.86076011, 1.13450045, 1.72759474,
#        0.81503785, 0.66207993, 1.04627466, 0.04519369, 0.06804576,
#        0.50032348, 0.5346236 , 0.13084774, 0.38677881, 0.46788939,
#        1.9433741 , 0.10282244, 0.13590107, 0.89917865, 0.6826425 ,
#        0.50492212, 0.65613004, 0.14680868, 0.262814  , 0.07769597,
#        0.02105276, 2.47520067, 0.01052759, 0.28216626, 0.58905156,
#        2.00373011, 0.50037571, 0.24641588, 0.09301193, 0.04016574,
#        1.25267637, 0.38386941, 1.44304071, 0.0747324 , 0.16808262,
#        0.15685311, 1.44632417, 0.8713005 , 0.35883243, 0.0818599 ,
#        3.67222748, 0.07212923, 0.06720004])

# %%
##### India

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
rating_india_1 = rng.poisson(34, 50)

# 2000 - 2019: Consumption increased
rating_india_2 = rng.poisson(21, 20)

# Round to 1 decimal
R_percapita_india_1 = percapita_india_1.round(1)
R_percapita_india_2 = percapita_india_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_india_1 = pd.DataFrame(R_percapita_india_1)
DF_percapita_india_2 = pd.DataFrame(R_percapita_india_2)

##### Indonesia

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
percapita_indo_1 = rng.poisson(19, 50)

# 2000 - 2019: Consumption increased
percapita_indo_2 = rng.poisson(36, 20)

# Round to 1 decimal
R_percapita_indo_1 = percapita_indo_1.round(1)
R_percapita_indo_2 = percapita_indo_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_indo_1 = pd.DataFrame(R_percapita_indo_1)
DF_percapita_indo_2 = pd.DataFrame(R_percapita_indo_2)

##### Austria

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
percapita_aust_1 = rng.poisson(45, 50)

# 2000 - 2019: Consumption increased
percapita_aust_2 = rng.poisson(17, 20)

# Round to 1 decimal
R_percapita_aust_1 = percapita_aust_1.round(1)
R_percapita_aust_2 = percapita_aust_2.round(1)

# Round to 1 decimal
R_percapita_aust_1 = percapita_aust_1.round(1)
R_percapita_aust_2 = percapita_aust_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_aust_1 = pd.DataFrame(R_percapita_aust_1)
DF_percapita_aust_2 = pd.DataFrame(R_percapita_aust_2)

frames_1 = [DF_percapita_india_1, DF_percapita_india_2, DF_percapita_indo_1, DF_percapita_indo_2,
               DF_percapita_aust_1, DF_percapita_aust_2]

prevalence = pd.concat(frames_1)
prevalence.columns = ["Prevalence(%)"]

##### India

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
percapita_india_1 = rng.poisson(34, 50)

# 2000 - 2019: Consumption increased
percapita_india_2 = rng.poisson(21, 20)

# Round to 1 decimal
R_percapita_india_1 = percapita_india_1.round(1)
R_percapita_india_2 = percapita_india_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_india_1 = pd.DataFrame(R_percapita_india_1)
DF_percapita_india_2 = pd.DataFrame(R_percapita_india_2)

##### Indonesia

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
percapita_indo_1 = rng.poisson(19, 50)

# 2000 - 2019: Consumption increased
percapita_indo_2 = rng.poisson(36, 20)

# Round to 1 decimal
R_percapita_indo_1 = percapita_indo_1.round(1)
R_percapita_indo_2 = percapita_indo_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_indo_1 = pd.DataFrame(R_percapita_indo_1)
DF_percapita_indo_2 = pd.DataFrame(R_percapita_indo_2)

##### Austria

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
percapita_aust_1 = rng.poisson(45, 50)

# 2000 - 2019: Consumption increased
percapita_aust_2 = rng.poisson(17, 20)

# Round to 1 decimal
R_percapita_aust_1 = percapita_aust_1.round(1)
R_percapita_aust_2 = percapita_aust_2.round(1)

# Round to 1 decimal
R_percapita_aust_1 = percapita_aust_1.round(1)
R_percapita_aust_2 = percapita_aust_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_aust_1 = pd.DataFrame(R_percapita_aust_1)
DF_percapita_aust_2 = pd.DataFrame(R_percapita_aust_2)

frames_1 = [DF_percapita_india_1, DF_percapita_india_2, DF_percapita_indo_1, DF_percapita_indo_2,
               DF_percapita_aust_1, DF_percapita_aust_2]

prevalence = pd.concat(frames_1)
prevalence.columns = ["Prevalence(%)"]

# %%
##### India

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
rating_india_1 = rng.poisson(34, 50)

# 2000 - 2019: Consumption increased
rating_india_2 = rng.poisson(21, 20)

# Round to 1 decimal
R_percapita_india_1 = percapita_india_1.round(1)
R_percapita_india_2 = percapita_india_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_india_1 = pd.DataFrame(R_percapita_india_1)
DF_percapita_india_2 = pd.DataFrame(R_percapita_india_2)

##### Indonesia

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
percapita_indo_1 = rng.poisson(19, 50)

# 2000 - 2019: Consumption increased
percapita_indo_2 = rng.poisson(36, 20)

# Round to 1 decimal
R_percapita_indo_1 = percapita_indo_1.round(1)
R_percapita_indo_2 = percapita_indo_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_indo_1 = pd.DataFrame(R_percapita_indo_1)
DF_percapita_indo_2 = pd.DataFrame(R_percapita_indo_2)

##### Austria

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
percapita_aust_1 = rng.poisson(45, 50)

# 2000 - 2019: Consumption increased
percapita_aust_2 = rng.poisson(17, 20)

# Round to 1 decimal
R_percapita_aust_1 = percapita_aust_1.round(1)
R_percapita_aust_2 = percapita_aust_2.round(1)

# Round to 1 decimal
R_percapita_aust_1 = percapita_aust_1.round(1)
R_percapita_aust_2 = percapita_aust_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_aust_1 = pd.DataFrame(R_percapita_aust_1)
DF_percapita_aust_2 = pd.DataFrame(R_percapita_aust_2)

frames_1 = [DF_percapita_india_1, DF_percapita_india_2, DF_percapita_indo_1, DF_percapita_indo_2,
               DF_percapita_aust_1, DF_percapita_aust_2]

prevalence = pd.concat(frames_1)
prevalence.columns = ["Prevalence(%)"]

##### India

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
percapita_india_1 = rng.poisson(34, 50)

# 2000 - 2019: Consumption increased
percapita_india_2 = rng.poisson(21, 20)

# Round to 1 decimal
R_percapita_india_1 = percapita_india_1.round(1)
R_percapita_india_2 = percapita_india_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_india_1 = pd.DataFrame(R_percapita_india_1)
DF_percapita_india_2 = pd.DataFrame(R_percapita_india_2)

##### Indonesia

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
percapita_indo_1 = rng.poisson(19, 50)

# 2000 - 2019: Consumption increased
percapita_indo_2 = rng.poisson(36, 20)

# Round to 1 decimal
R_percapita_indo_1 = percapita_indo_1.round(1)
R_percapita_indo_2 = percapita_indo_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_indo_1 = pd.DataFrame(R_percapita_indo_1)
DF_percapita_indo_2 = pd.DataFrame(R_percapita_indo_2)

##### Austria

rng = np.random.default_rng(0)

# Generate random data for number of cigarettes consumed per person (15 years or older) 

# 1950 - 1999: Consumption of cigs remained pretty steady
# Use np.poisson to create  to create
percapita_aust_1 = rng.poisson(45, 50)

# 2000 - 2019: Consumption increased
percapita_aust_2 = rng.poisson(17, 20)

# Round to 1 decimal
R_percapita_aust_1 = percapita_aust_1.round(1)
R_percapita_aust_2 = percapita_aust_2.round(1)

# Round to 1 decimal
R_percapita_aust_1 = percapita_aust_1.round(1)
R_percapita_aust_2 = percapita_aust_2.round(1)

# Transform Arrays into DataFrames
DF_percapita_aust_1 = pd.DataFrame(R_percapita_aust_1)
DF_percapita_aust_2 = pd.DataFrame(R_percapita_aust_2)

frames_1 = [DF_percapita_india_1, DF_percapita_india_2, DF_percapita_indo_1, DF_percapita_indo_2,
               DF_percapita_aust_1, DF_percapita_aust_2]

prevalence = pd.concat(frames_1)
prevalence.columns = ["Prevalence(%)"]
